# %% [markdown]
# <a href="https://colab.research.google.com/github/arturoliduena/cifar10-image-recognition/blob/main/versions/cnn_cifar10_tf2_v7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Librerias & Google Drive
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
from tensorflow import keras as ks
from matplotlib import pyplot as plt
import numpy as np
import time
import datetime

# %%
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam, SGD

from tensorflow.keras.applications import vgg16
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint

# %% [markdown]
# Incorporamos la carpeta de Google Drive para poder "guardar" nuestros modelos
#
# 1. Abrir barra lateral de Carpeta
# 2.  Hacer click en carpeta con logo de Google Drive

# %%
# Aquí iria el codigo para conectarse a Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train_scaled, x_test_scaled = x_train / 255.0, x_test / 255.0

# %%
y_train_label = y_train

y_test
y_train
# Out:
# array([[6],
#        [9],
#        [9],
#        ...,
#        [9],
#        [1],
#        [1]], dtype=uint8)

# %%
x_val_scaled = x_train_scaled[-10000:]
y_val = y_train[-10000:]

x_train_scaled = x_train_scaled[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# ## 2. Arquitectura de red del modelo - Proyecto 0

# %%
vgg = vgg16.VGG16(include_top=False, weights="imagenet", input_shape=(32, 32,3))
vgg.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  block1_conv1 (Conv2D)       (None, 32, 32, 64)        1792
#
#  block1_conv2 (Conv2D)       (None, 32, 32, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 16, 16, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 16, 16, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 16, 16, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 8, 8, 128)         0
#
#  block3_conv1 (Conv2D)       (None, 8, 8, 256)         295168
#
#  block3_conv2 (Conv2D)       (None, 8, 8, 256)         590080
#
#  block3_conv3 (Conv2D)       (None, 8, 8, 256)         590080
#
#  block3_pool (MaxPooling2D)  (None, 4, 4, 256)         0
#
#  block4_conv1 (Conv2D)       (None, 4, 4, 512)         1180160
#
#  block4_conv2 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block4_conv3 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block4_pool (MaxPooling2D)  (None, 2, 2, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 2, 2, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 2, 2, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 2, 2, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 1, 1, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
output = vgg.layers[-1].output
new_output_layer = ks.layers.Flatten()(output)
#new_output_layer = ks.layers.Conv2D(512, (1,1), activation='relu')(output)

vgg_model = Model(vgg.input, new_output_layer)

# %%
vgg_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  block1_conv1 (Conv2D)       (None, 32, 32, 64)        1792
#
#  block1_conv2 (Conv2D)       (None, 32, 32, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 16, 16, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 16, 16, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 16, 16, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 8, 8, 128)         0
#
#  block3_conv1 (Conv2D)       (None, 8, 8, 256)         295168
#
#  block3_conv2 (Conv2D)       (None, 8, 8, 256)         590080
#
#  block3_conv3 (Conv2D)       (None, 8, 8, 256)         590080
#
#  block3_pool (MaxPooling2D)  (None, 4, 4, 256)         0
#
#  block4_conv1 (Conv2D)       (None, 4, 4, 512)         1180160
#
#  block4_conv2 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block4_conv3 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block4_pool (MaxPooling2D)  (None, 2, 2, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 2, 2, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 2, 2, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 2, 2, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 1, 1, 512)         0
#
#  flatten (Flatten)           (None, 512)               0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
print(vgg_model.trainable)
# Out:
# True

# %%
for layer in vgg_model.layers:
  print(layer, layer.name, layer.trainable)
# Out:
# <keras.engine.input_layer.InputLayer object at 0x7f2b79c0c090> input_1 True
# <keras.layers.convolutional.Conv2D object at 0x7f2bf3192050> block1_conv1 True
# <keras.layers.convolutional.Conv2D object at 0x7f2b71fa2c50> block1_conv2 True
# <keras.layers.pooling.MaxPooling2D object at 0x7f2b71671fd0> block1_pool True
# <keras.layers.convolutional.Conv2D object at 0x7f2b7168b750> block2_conv1 True
# <keras.layers.convolutional.Conv2D object at 0x7f2b601aa150> block2_conv2 True
# <keras.layers.pooling.MaxPooling2D object at 0x7f2b601b24d0> block2_pool True
# <keras.layers.convolutional.Conv2D object at 0x7f2b601b20d0> block3_conv1 True
# <keras.layers.convolutional.Conv2D object at 0x7f2b601b5b50> block3_conv2 True
# <keras.layers.convolutional.Conv2D object at 0x7f2b601b9f90> block3_conv3 True
# <keras.layers.pooling.MaxPooling2D object at 0x7f2b601c0b50> block3_pool True
# <keras.layers.convolutional.Conv2D object at 0x7f2b765385d0> block4_conv1 True
# <keras.layers.convolutional.Conv2D object at 0x7f2b71671050> block4_conv2 True
# <keras.layers.convolutional.Conv2D object at 0x7f2b601d2b10> block4_conv3 True
# <keras.layers.pooling.MaxPooling2D object at 0x7f2b601d26d0> block4_pool True
# <keras.layers.convolutional.Conv2D object at 0x7f2b601da910> block5_conv1 True
# <keras.layers.convolutional.Conv2D object at 0x7f2b60161150> block5_conv2 True
# <keras.layers.convolutional.Conv2D object at 0x7f2b601689d0> block5_conv3 True
# <keras.layers.pooling.MaxPooling2D object at 0x7f2b601dd190> block5_pool True
# <keras.layers.core.flatten.Flatten object at 0x7f2b6019cb90> flatten True

# %%
for layer in vgg_model.layers:
  layer.trainable = False

# %%
for layer in vgg_model.layers:
  print(layer, layer.name, layer.trainable)
# Out:
# <keras.engine.input_layer.InputLayer object at 0x7f2b79c0c090> input_1 False
# <keras.layers.convolutional.Conv2D object at 0x7f2bf3192050> block1_conv1 False
# <keras.layers.convolutional.Conv2D object at 0x7f2b71fa2c50> block1_conv2 False
# <keras.layers.pooling.MaxPooling2D object at 0x7f2b71671fd0> block1_pool False
# <keras.layers.convolutional.Conv2D object at 0x7f2b7168b750> block2_conv1 False
# <keras.layers.convolutional.Conv2D object at 0x7f2b601aa150> block2_conv2 False
# <keras.layers.pooling.MaxPooling2D object at 0x7f2b601b24d0> block2_pool False
# <keras.layers.convolutional.Conv2D object at 0x7f2b601b20d0> block3_conv1 False
# <keras.layers.convolutional.Conv2D object at 0x7f2b601b5b50> block3_conv2 False
# <keras.layers.convolutional.Conv2D object at 0x7f2b601b9f90> block3_conv3 False
# <keras.layers.pooling.MaxPooling2D object at 0x7f2b601c0b50> block3_pool False
# <keras.layers.convolutional.Conv2D object at 0x7f2b765385d0> block4_conv1 False
# <keras.layers.convolutional.Conv2D object at 0x7f2b71671050> block4_conv2 False
# <keras.layers.convolutional.Conv2D object at 0x7f2b601d2b10> block4_conv3 False
# <keras.layers.pooling.MaxPooling2D object at 0x7f2b601d26d0> block4_pool False
# <keras.layers.convolutional.Conv2D object at 0x7f2b601da910> block5_conv1 False
# <keras.layers.convolutional.Conv2D object at 0x7f2b60161150> block5_conv2 False
# <keras.layers.convolutional.Conv2D object at 0x7f2b601689d0> block5_conv3 False
# <keras.layers.pooling.MaxPooling2D object at 0x7f2b601dd190> block5_pool False
# <keras.layers.core.flatten.Flatten object at 0x7f2b6019cb90> flatten False

# %%
model = ks.Sequential()


model.add(ks.layers.InputLayer(input_shape=(512))) 
model.add(ks.layers.Dense(512, activation='relu'))
model.add(ks.layers.Dropout(0.3))
model.add(ks.layers.Dense(512, activation='relu'))
model.add(ks.layers.Dropout(0.3))
model.add(ks.layers.Dense(10, activation='softmax'))

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               262656
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 530,442
# Trainable params: 530,442
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 3. Optimizador, función error

# %%
new_adam = Adam(learning_rate=2e-5)

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer=new_adam, metrics=['accuracy'])

# %%
#vgg.compile(optimizer='Adam',
#              loss='sparse_categorical_crossentropy',
#              metrics=['accuracy'])

# %% [markdown]
# ## 4. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck'
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
# Pintemos una muestra de las las imagenes del dataset MNIST

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train_label[i,0]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(40000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución espera una matriz de 4 campos** (más parecido a "imagenes"), en el caso de MNIST. CIFAR10 ya tiene el shape adecuado, así que no tenemos que hacer nada, pero como siempre decimos: es mejor que comprobeis su tamaño.
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %%
# Validamos el resultado
print('Train: X=%s, y=%s' % (x_train_scaled.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test_scaled.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val_scaled.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)
# Validation: X=(10000, 32, 32, 3), y=(10000, 1)

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
# Llevamos las imagenes desde su origen al cuello de botella de VGG16, justo después del Flatten()
def alcuellodebotella(model, x_data):
  return model.predict(x_data)

# %%
x_train_post_vgg = alcuellodebotella(vgg_model, x_train_scaled)
x_test_post_vgg = alcuellodebotella(vgg_model, x_test_scaled)
x_val_post_vgg = alcuellodebotella(vgg_model, x_val_scaled)

# %% [markdown]
# ## 5.1 Callbacks

# %%
# Callback con EarlyStopping basado en Accuracy
callback_accuracy = EarlyStopping(monitor='val_accuracy', patience=10)

# Callback con EarlyStopping basada en Loss
callback_loss = EarlyStopping(monitor='val_loss', patience=10)

callback_modelcheckpoint = ModelCheckpoint('/tmp/modelchk', monitor='val_accuracy', 
                                           verbose=1, save_best_only=True, 
                                           save_weights_only=True)

# %%
t = time.perf_counter()

# %%
history = model.fit(x_train_post_vgg, y_train, epochs=200, 
                    use_multiprocessing=False, batch_size=32, callbacks=[callback_modelcheckpoint, callback_loss, callback_accuracy],
                    validation_data=(x_val_post_vgg, y_val))
# Out:
# Epoch 1/200
# 1241/1250 [============================>.] - ETA: 0s - loss: 2.0641 - accuracy: 0.2539
# Epoch 1: val_accuracy improved from -inf to 0.44010, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 6s 4ms/step - loss: 2.0617 - accuracy: 0.2548 - val_loss: 1.7126 - val_accuracy: 0.4401
# Epoch 2/200
# 1250/1250 [==============================] - ETA: 0s - loss: 1.6996 - accuracy: 0.4044
# Epoch 2: val_accuracy improved from 0.44010 to 0.48140, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.6996 - accuracy: 0.4044 - val_loss: 1.5141 - val_accuracy: 0.4814
# Epoch 3/200
# 1246/1250 [============================>.] - ETA: 0s - loss: 1.5691 - accuracy: 0.4512
# Epoch 3: val_accuracy improved from 0.48140 to 0.50160, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.5686 - accuracy: 0.4514 - val_loss: 1.4329 - val_accuracy: 0.5016
# Epoch 4/200
# 1248/1250 [============================>.] - ETA: 0s - loss: 1.4931 - accuracy: 0.4777
# Epoch 4: val_accuracy improved from 0.50160 to 0.51340, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.4930 - accuracy: 0.4776 - val_loss: 1.3824 - val_accuracy: 0.5134
# Epoch 5/200
# 1244/1250 [============================>.] - ETA: 0s - loss: 1.4491 - accuracy: 0.4908
# Epoch 5: val_accuracy improved from 0.51340 to 0.52730, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.4490 - accuracy: 0.4908 - val_loss: 1.3466 - val_accuracy: 0.5273
# Epoch 6/200
# 1236/1250 [============================>.] - ETA: 0s - loss: 1.4093 - accuracy: 0.5053
# Epoch 6: val_accuracy improved from 0.52730 to 0.53510, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 6s 4ms/step - loss: 1.4086 - accuracy: 0.5054 - val_loss: 1.3195 - val_accuracy: 0.5351
# Epoch 7/200
# 1242/1250 [============================>.] - ETA: 0s - loss: 1.3787 - accuracy: 0.5172
# Epoch 7: val_accuracy improved from 0.53510 to 0.54460, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.3790 - accuracy: 0.5171 - val_loss: 1.2965 - val_accuracy: 0.5446
# Epoch 8/200
# 1239/1250 [============================>.] - ETA: 0s - loss: 1.3535 - accuracy: 0.5271
# Epoch 8: val_accuracy improved from 0.54460 to 0.55060, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.3526 - accuracy: 0.5274 - val_loss: 1.2818 - val_accuracy: 0.5506
# Epoch 9/200
# 1241/1250 [============================>.] - ETA: 0s - loss: 1.3289 - accuracy: 0.5351
# Epoch 9: val_accuracy improved from 0.55060 to 0.55740, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.3291 - accuracy: 0.5350 - val_loss: 1.2638 - val_accuracy: 0.5574
# Epoch 10/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.3099 - accuracy: 0.5435
# Epoch 10: val_accuracy improved from 0.55740 to 0.56210, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.3098 - accuracy: 0.5435 - val_loss: 1.2495 - val_accuracy: 0.5621
# Epoch 11/200
# 1244/1250 [============================>.] - ETA: 0s - loss: 1.2947 - accuracy: 0.5460
# Epoch 11: val_accuracy improved from 0.56210 to 0.56550, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.2945 - accuracy: 0.5459 - val_loss: 1.2365 - val_accuracy: 0.5655
# Epoch 12/200
# 1241/1250 [============================>.] - ETA: 0s - loss: 1.2746 - accuracy: 0.5513
# Epoch 12: val_accuracy improved from 0.56550 to 0.57070, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 6s 4ms/step - loss: 1.2745 - accuracy: 0.5513 - val_loss: 1.2270 - val_accuracy: 0.5707
# Epoch 13/200
# 1240/1250 [============================>.] - ETA: 0s - loss: 1.2609 - accuracy: 0.5590
# Epoch 13: val_accuracy improved from 0.57070 to 0.57340, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.2614 - accuracy: 0.5586 - val_loss: 1.2144 - val_accuracy: 0.5734
# Epoch 14/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.2452 - accuracy: 0.5644
# Epoch 14: val_accuracy improved from 0.57340 to 0.57420, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.2450 - accuracy: 0.5645 - val_loss: 1.2072 - val_accuracy: 0.5742
# Epoch 15/200
# 1239/1250 [============================>.] - ETA: 0s - loss: 1.2334 - accuracy: 0.5677
# Epoch 15: val_accuracy improved from 0.57420 to 0.57740, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.2330 - accuracy: 0.5675 - val_loss: 1.1992 - val_accuracy: 0.5774
# Epoch 16/200
# 1238/1250 [============================>.] - ETA: 0s - loss: 1.2226 - accuracy: 0.5722
# Epoch 16: val_accuracy improved from 0.57740 to 0.58140, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.2224 - accuracy: 0.5725 - val_loss: 1.1912 - val_accuracy: 0.5814
# Epoch 17/200
# 1247/1250 [============================>.] - ETA: 0s - loss: 1.2127 - accuracy: 0.5759
# Epoch 17: val_accuracy improved from 0.58140 to 0.58410, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.2130 - accuracy: 0.5758 - val_loss: 1.1839 - val_accuracy: 0.5841
# Epoch 18/200
# 1242/1250 [============================>.] - ETA: 0s - loss: 1.2013 - accuracy: 0.5801
# Epoch 18: val_accuracy improved from 0.58410 to 0.58690, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.2013 - accuracy: 0.5802 - val_loss: 1.1788 - val_accuracy: 0.5869
# Epoch 19/200
# 1246/1250 [============================>.] - ETA: 0s - loss: 1.1962 - accuracy: 0.5820
# Epoch 19: val_accuracy improved from 0.58690 to 0.58770, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.1962 - accuracy: 0.5821 - val_loss: 1.1721 - val_accuracy: 0.5877
# Epoch 20/200
# 1245/1250 [============================>.] - ETA: 0s - loss: 1.1840 - accuracy: 0.5860
# Epoch 20: val_accuracy improved from 0.58770 to 0.59020, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.1837 - accuracy: 0.5862 - val_loss: 1.1679 - val_accuracy: 0.5902
# Epoch 21/200
# 1246/1250 [============================>.] - ETA: 0s - loss: 1.1751 - accuracy: 0.5867
# Epoch 21: val_accuracy improved from 0.59020 to 0.59040, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.1749 - accuracy: 0.5866 - val_loss: 1.1653 - val_accuracy: 0.5904
# Epoch 22/200
# 1242/1250 [============================>.] - ETA: 0s - loss: 1.1690 - accuracy: 0.5928
# Epoch 22: val_accuracy improved from 0.59040 to 0.59380, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.1691 - accuracy: 0.5928 - val_loss: 1.1575 - val_accuracy: 0.5938
# Epoch 23/200
# 1245/1250 [============================>.] - ETA: 0s - loss: 1.1628 - accuracy: 0.5914
# Epoch 23: val_accuracy did not improve from 0.59380
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.1623 - accuracy: 0.5914 - val_loss: 1.1521 - val_accuracy: 0.5929
# Epoch 24/200
# 1240/1250 [============================>.] - ETA: 0s - loss: 1.1498 - accuracy: 0.5976
# Epoch 24: val_accuracy improved from 0.59380 to 0.59510, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.1494 - accuracy: 0.5978 - val_loss: 1.1478 - val_accuracy: 0.5951
# Epoch 25/200
# 1241/1250 [============================>.] - ETA: 0s - loss: 1.1402 - accuracy: 0.6014
# Epoch 25: val_accuracy improved from 0.59510 to 0.59910, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.1403 - accuracy: 0.6012 - val_loss: 1.1443 - val_accuracy: 0.5991
# Epoch 26/200
# 1239/1250 [============================>.] - ETA: 0s - loss: 1.1346 - accuracy: 0.6032
# Epoch 26: val_accuracy did not improve from 0.59910
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.1348 - accuracy: 0.6033 - val_loss: 1.1414 - val_accuracy: 0.5978
# Epoch 27/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.1267 - accuracy: 0.6044
# Epoch 27: val_accuracy improved from 0.59910 to 0.59920, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.1267 - accuracy: 0.6043 - val_loss: 1.1370 - val_accuracy: 0.5992
# Epoch 28/200
# 1250/1250 [==============================] - ETA: 0s - loss: 1.1199 - accuracy: 0.6104
# Epoch 28: val_accuracy improved from 0.59920 to 0.60150, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.1199 - accuracy: 0.6104 - val_loss: 1.1338 - val_accuracy: 0.6015
# Epoch 29/200
# 1243/1250 [============================>.] - ETA: 0s - loss: 1.1157 - accuracy: 0.6089
# Epoch 29: val_accuracy improved from 0.60150 to 0.60490, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.1151 - accuracy: 0.6093 - val_loss: 1.1306 - val_accuracy: 0.6049
# Epoch 30/200
# 1244/1250 [============================>.] - ETA: 0s - loss: 1.1088 - accuracy: 0.6119
# Epoch 30: val_accuracy improved from 0.60490 to 0.60560, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 6s 4ms/step - loss: 1.1085 - accuracy: 0.6120 - val_loss: 1.1265 - val_accuracy: 0.6056
# Epoch 31/200
# 1244/1250 [============================>.] - ETA: 0s - loss: 1.1020 - accuracy: 0.6156
# Epoch 31: val_accuracy improved from 0.60560 to 0.60710, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.1024 - accuracy: 0.6152 - val_loss: 1.1225 - val_accuracy: 0.6071
# Epoch 32/200
# 1238/1250 [============================>.] - ETA: 0s - loss: 1.0981 - accuracy: 0.6164
# Epoch 32: val_accuracy improved from 0.60710 to 0.60800, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 6s 4ms/step - loss: 1.0990 - accuracy: 0.6162 - val_loss: 1.1205 - val_accuracy: 0.6080
# Epoch 33/200
# 1236/1250 [============================>.] - ETA: 0s - loss: 1.0924 - accuracy: 0.6162
# Epoch 33: val_accuracy improved from 0.60800 to 0.61040, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.0918 - accuracy: 0.6167 - val_loss: 1.1173 - val_accuracy: 0.6104
# Epoch 34/200
# 1236/1250 [============================>.] - ETA: 0s - loss: 1.0816 - accuracy: 0.6219
# Epoch 34: val_accuracy improved from 0.61040 to 0.61090, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.0829 - accuracy: 0.6213 - val_loss: 1.1141 - val_accuracy: 0.6109
# Epoch 35/200
# 1238/1250 [============================>.] - ETA: 0s - loss: 1.0797 - accuracy: 0.6223
# Epoch 35: val_accuracy improved from 0.61090 to 0.61140, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.0802 - accuracy: 0.6219 - val_loss: 1.1140 - val_accuracy: 0.6114
# Epoch 36/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.0711 - accuracy: 0.6260
# Epoch 36: val_accuracy improved from 0.61140 to 0.61170, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.0709 - accuracy: 0.6261 - val_loss: 1.1112 - val_accuracy: 0.6117
# Epoch 37/200
# 1244/1250 [============================>.] - ETA: 0s - loss: 1.0680 - accuracy: 0.6270
# Epoch 37: val_accuracy improved from 0.61170 to 0.61250, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.0680 - accuracy: 0.6271 - val_loss: 1.1082 - val_accuracy: 0.6125
# Epoch 38/200
# 1250/1250 [==============================] - ETA: 0s - loss: 1.0631 - accuracy: 0.6296
# Epoch 38: val_accuracy improved from 0.61250 to 0.61560, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.0631 - accuracy: 0.6296 - val_loss: 1.1044 - val_accuracy: 0.6156
# Epoch 39/200
# 1240/1250 [============================>.] - ETA: 0s - loss: 1.0556 - accuracy: 0.6312
# Epoch 39: val_accuracy improved from 0.61560 to 0.61650, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.0549 - accuracy: 0.6314 - val_loss: 1.1038 - val_accuracy: 0.6165
# Epoch 40/200
# 1242/1250 [============================>.] - ETA: 0s - loss: 1.0554 - accuracy: 0.6302
# Epoch 40: val_accuracy improved from 0.61650 to 0.61760, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.0554 - accuracy: 0.6301 - val_loss: 1.1008 - val_accuracy: 0.6176
# Epoch 41/200
# 1236/1250 [============================>.] - ETA: 0s - loss: 1.0460 - accuracy: 0.6334
# Epoch 41: val_accuracy improved from 0.61760 to 0.61930, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.0454 - accuracy: 0.6337 - val_loss: 1.0974 - val_accuracy: 0.6193
# Epoch 42/200
# 1243/1250 [============================>.] - ETA: 0s - loss: 1.0443 - accuracy: 0.6368
# Epoch 42: val_accuracy did not improve from 0.61930
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.0442 - accuracy: 0.6369 - val_loss: 1.0961 - val_accuracy: 0.6187
# Epoch 43/200
# 1250/1250 [==============================] - ETA: 0s - loss: 1.0391 - accuracy: 0.6373
# Epoch 43: val_accuracy did not improve from 0.61930
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.0391 - accuracy: 0.6373 - val_loss: 1.0942 - val_accuracy: 0.6190
# Epoch 44/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.0329 - accuracy: 0.6396
# Epoch 44: val_accuracy did not improve from 0.61930
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.0330 - accuracy: 0.6395 - val_loss: 1.0944 - val_accuracy: 0.6181
# Epoch 45/200
# 1237/1250 [============================>.] - ETA: 0s - loss: 1.0289 - accuracy: 0.6408
# Epoch 45: val_accuracy improved from 0.61930 to 0.62050, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.0293 - accuracy: 0.6407 - val_loss: 1.0920 - val_accuracy: 0.6205
# Epoch 46/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.0207 - accuracy: 0.6413
# Epoch 46: val_accuracy improved from 0.62050 to 0.62270, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.0209 - accuracy: 0.6412 - val_loss: 1.0913 - val_accuracy: 0.6227
# Epoch 47/200
# 1237/1250 [============================>.] - ETA: 0s - loss: 1.0212 - accuracy: 0.6445
# Epoch 47: val_accuracy improved from 0.62270 to 0.62350, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.0209 - accuracy: 0.6447 - val_loss: 1.0890 - val_accuracy: 0.6235
# Epoch 48/200
# 1246/1250 [============================>.] - ETA: 0s - loss: 1.0154 - accuracy: 0.6464
# Epoch 48: val_accuracy did not improve from 0.62350
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.0158 - accuracy: 0.6463 - val_loss: 1.0876 - val_accuracy: 0.6227
# Epoch 49/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.0091 - accuracy: 0.6482
# Epoch 49: val_accuracy did not improve from 0.62350
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.0091 - accuracy: 0.6482 - val_loss: 1.0869 - val_accuracy: 0.6219
# Epoch 50/200
# 1236/1250 [============================>.] - ETA: 0s - loss: 1.0048 - accuracy: 0.6482
# Epoch 50: val_accuracy did not improve from 0.62350
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.0049 - accuracy: 0.6481 - val_loss: 1.0853 - val_accuracy: 0.6229
# Epoch 51/200
# 1239/1250 [============================>.] - ETA: 0s - loss: 1.0000 - accuracy: 0.6491
# Epoch 51: val_accuracy improved from 0.62350 to 0.62550, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.0000 - accuracy: 0.6491 - val_loss: 1.0851 - val_accuracy: 0.6255
# Epoch 52/200
# 1236/1250 [============================>.] - ETA: 0s - loss: 0.9945 - accuracy: 0.6495
# Epoch 52: val_accuracy improved from 0.62550 to 0.62730, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.9951 - accuracy: 0.6491 - val_loss: 1.0845 - val_accuracy: 0.6273
# Epoch 53/200
# 1247/1250 [============================>.] - ETA: 0s - loss: 0.9903 - accuracy: 0.6556
# Epoch 53: val_accuracy did not improve from 0.62730
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.9899 - accuracy: 0.6557 - val_loss: 1.0810 - val_accuracy: 0.6261
# Epoch 54/200
# 1244/1250 [============================>.] - ETA: 0s - loss: 0.9843 - accuracy: 0.6559
# Epoch 54: val_accuracy did not improve from 0.62730
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.9845 - accuracy: 0.6558 - val_loss: 1.0843 - val_accuracy: 0.6270
# Epoch 55/200
# 1236/1250 [============================>.] - ETA: 0s - loss: 0.9867 - accuracy: 0.6560
# Epoch 55: val_accuracy did not improve from 0.62730
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.9866 - accuracy: 0.6556 - val_loss: 1.0795 - val_accuracy: 0.6264
# Epoch 56/200
# 1246/1250 [============================>.] - ETA: 0s - loss: 0.9808 - accuracy: 0.6552
# Epoch 56: val_accuracy improved from 0.62730 to 0.62830, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.9811 - accuracy: 0.6551 - val_loss: 1.0791 - val_accuracy: 0.6283
# Epoch 57/200
# 1242/1250 [============================>.] - ETA: 0s - loss: 0.9745 - accuracy: 0.6601
# Epoch 57: val_accuracy improved from 0.62830 to 0.63040, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.9745 - accuracy: 0.6603 - val_loss: 1.0784 - val_accuracy: 0.6304
# Epoch 58/200
# 1245/1250 [============================>.] - ETA: 0s - loss: 0.9690 - accuracy: 0.6606
# Epoch 58: val_accuracy did not improve from 0.63040
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.9688 - accuracy: 0.6607 - val_loss: 1.0766 - val_accuracy: 0.6291
# Epoch 59/200
# 1238/1250 [============================>.] - ETA: 0s - loss: 0.9664 - accuracy: 0.6640
# Epoch 59: val_accuracy did not improve from 0.63040
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.9662 - accuracy: 0.6640 - val_loss: 1.0760 - val_accuracy: 0.6286
# Epoch 60/200
# 1241/1250 [============================>.] - ETA: 0s - loss: 0.9612 - accuracy: 0.6635
# Epoch 60: val_accuracy did not improve from 0.63040
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.9606 - accuracy: 0.6636 - val_loss: 1.0747 - val_accuracy: 0.6295
# Epoch 61/200
# 1235/1250 [============================>.] - ETA: 0s - loss: 0.9608 - accuracy: 0.6649
# Epoch 61: val_accuracy did not improve from 0.63040
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.9598 - accuracy: 0.6653 - val_loss: 1.0740 - val_accuracy: 0.6292
# Epoch 62/200
# 1243/1250 [============================>.] - ETA: 0s - loss: 0.9528 - accuracy: 0.6666
# Epoch 62: val_accuracy improved from 0.63040 to 0.63160, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.9533 - accuracy: 0.6664 - val_loss: 1.0739 - val_accuracy: 0.6316
# Epoch 63/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.9514 - accuracy: 0.6652
# Epoch 63: val_accuracy did not improve from 0.63160
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.9515 - accuracy: 0.6652 - val_loss: 1.0734 - val_accuracy: 0.6301
# Epoch 64/200
# 1245/1250 [============================>.] - ETA: 0s - loss: 0.9476 - accuracy: 0.6693
# Epoch 64: val_accuracy did not improve from 0.63160
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.9477 - accuracy: 0.6692 - val_loss: 1.0738 - val_accuracy: 0.6285
# Epoch 65/200
# 1244/1250 [============================>.] - ETA: 0s - loss: 0.9436 - accuracy: 0.6684
# Epoch 65: val_accuracy did not improve from 0.63160
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.9435 - accuracy: 0.6684 - val_loss: 1.0716 - val_accuracy: 0.6312
# Epoch 66/200
# 1243/1250 [============================>.] - ETA: 0s - loss: 0.9353 - accuracy: 0.6726
# Epoch 66: val_accuracy improved from 0.63160 to 0.63290, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.9356 - accuracy: 0.6725 - val_loss: 1.0699 - val_accuracy: 0.6329
# Epoch 67/200
# 1241/1250 [============================>.] - ETA: 0s - loss: 0.9330 - accuracy: 0.6735
# Epoch 67: val_accuracy improved from 0.63290 to 0.63360, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.9333 - accuracy: 0.6733 - val_loss: 1.0706 - val_accuracy: 0.6336
# Epoch 68/200
# 1240/1250 [============================>.] - ETA: 0s - loss: 0.9312 - accuracy: 0.6750
# Epoch 68: val_accuracy did not improve from 0.63360
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.9309 - accuracy: 0.6752 - val_loss: 1.0708 - val_accuracy: 0.6331
# Epoch 69/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.9260 - accuracy: 0.6761
# Epoch 69: val_accuracy did not improve from 0.63360
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.9257 - accuracy: 0.6762 - val_loss: 1.0682 - val_accuracy: 0.6334
# Epoch 70/200
# 1247/1250 [============================>.] - ETA: 0s - loss: 0.9224 - accuracy: 0.6779
# Epoch 70: val_accuracy improved from 0.63360 to 0.63480, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.9225 - accuracy: 0.6779 - val_loss: 1.0676 - val_accuracy: 0.6348
# Epoch 71/200
# 1250/1250 [==============================] - ETA: 0s - loss: 0.9180 - accuracy: 0.6798
# Epoch 71: val_accuracy did not improve from 0.63480
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.9180 - accuracy: 0.6798 - val_loss: 1.0702 - val_accuracy: 0.6329
# Epoch 72/200
# 1239/1250 [============================>.] - ETA: 0s - loss: 0.9128 - accuracy: 0.6831
# Epoch 72: val_accuracy improved from 0.63480 to 0.63490, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.9133 - accuracy: 0.6828 - val_loss: 1.0683 - val_accuracy: 0.6349
# Epoch 73/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.9080 - accuracy: 0.6814
# Epoch 73: val_accuracy did not improve from 0.63490
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.9079 - accuracy: 0.6815 - val_loss: 1.0674 - val_accuracy: 0.6344
# Epoch 74/200
# 1239/1250 [============================>.] - ETA: 0s - loss: 0.9072 - accuracy: 0.6851
# Epoch 74: val_accuracy did not improve from 0.63490
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.9079 - accuracy: 0.6848 - val_loss: 1.0664 - val_accuracy: 0.6343
# Epoch 75/200
# 1246/1250 [============================>.] - ETA: 0s - loss: 0.9062 - accuracy: 0.6847
# Epoch 75: val_accuracy did not improve from 0.63490
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.9064 - accuracy: 0.6847 - val_loss: 1.0674 - val_accuracy: 0.6348
# Epoch 76/200
# 1240/1250 [============================>.] - ETA: 0s - loss: 0.8983 - accuracy: 0.6866
# Epoch 76: val_accuracy improved from 0.63490 to 0.63620, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.8982 - accuracy: 0.6865 - val_loss: 1.0654 - val_accuracy: 0.6362
# Epoch 77/200
# 1243/1250 [============================>.] - ETA: 0s - loss: 0.8925 - accuracy: 0.6877
# Epoch 77: val_accuracy improved from 0.63620 to 0.63650, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.8925 - accuracy: 0.6876 - val_loss: 1.0668 - val_accuracy: 0.6365
# Epoch 78/200
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.8939 - accuracy: 0.6865
# Epoch 78: val_accuracy did not improve from 0.63650
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.8941 - accuracy: 0.6864 - val_loss: 1.0681 - val_accuracy: 0.6352
# Epoch 79/200
# 1247/1250 [============================>.] - ETA: 0s - loss: 0.8899 - accuracy: 0.6889
# Epoch 79: val_accuracy did not improve from 0.63650
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.8896 - accuracy: 0.6890 - val_loss: 1.0659 - val_accuracy: 0.6352
# Epoch 80/200
# 1239/1250 [============================>.] - ETA: 0s - loss: 0.8867 - accuracy: 0.6869
# Epoch 80: val_accuracy improved from 0.63650 to 0.63900, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.8874 - accuracy: 0.6867 - val_loss: 1.0655 - val_accuracy: 0.6390
# Epoch 81/200
# 1243/1250 [============================>.] - ETA: 0s - loss: 0.8830 - accuracy: 0.6911
# Epoch 81: val_accuracy did not improve from 0.63900
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.8827 - accuracy: 0.6912 - val_loss: 1.0660 - val_accuracy: 0.6369
# Epoch 82/200
# 1239/1250 [============================>.] - ETA: 0s - loss: 0.8797 - accuracy: 0.6917
# Epoch 82: val_accuracy did not improve from 0.63900
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.8805 - accuracy: 0.6913 - val_loss: 1.0663 - val_accuracy: 0.6361
# Epoch 83/200
# 1239/1250 [============================>.] - ETA: 0s - loss: 0.8781 - accuracy: 0.6937
# Epoch 83: val_accuracy did not improve from 0.63900
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.8776 - accuracy: 0.6939 - val_loss: 1.0665 - val_accuracy: 0.6363
# Epoch 84/200
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.8705 - accuracy: 0.6941
# Epoch 84: val_accuracy did not improve from 0.63900
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.8704 - accuracy: 0.6941 - val_loss: 1.0652 - val_accuracy: 0.6379
# Epoch 85/200
# 1236/1250 [============================>.] - ETA: 0s - loss: 0.8686 - accuracy: 0.6979
# Epoch 85: val_accuracy did not improve from 0.63900
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.8679 - accuracy: 0.6980 - val_loss: 1.0657 - val_accuracy: 0.6373
# Epoch 86/200
# 1250/1250 [==============================] - ETA: 0s - loss: 0.8648 - accuracy: 0.6966
# Epoch 86: val_accuracy did not improve from 0.63900
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.8648 - accuracy: 0.6966 - val_loss: 1.0640 - val_accuracy: 0.6373
# Epoch 87/200
# 1240/1250 [============================>.] - ETA: 0s - loss: 0.8623 - accuracy: 0.6991
# Epoch 87: val_accuracy improved from 0.63900 to 0.63910, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.8620 - accuracy: 0.6990 - val_loss: 1.0637 - val_accuracy: 0.6391
# Epoch 88/200
# 1238/1250 [============================>.] - ETA: 0s - loss: 0.8584 - accuracy: 0.7009
# Epoch 88: val_accuracy did not improve from 0.63910
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.8582 - accuracy: 0.7009 - val_loss: 1.0666 - val_accuracy: 0.6360
# Epoch 89/200
# 1245/1250 [============================>.] - ETA: 0s - loss: 0.8531 - accuracy: 0.7029
# Epoch 89: val_accuracy did not improve from 0.63910
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.8533 - accuracy: 0.7029 - val_loss: 1.0658 - val_accuracy: 0.6370
# Epoch 90/200
# 1245/1250 [============================>.] - ETA: 0s - loss: 0.8536 - accuracy: 0.7039
# Epoch 90: val_accuracy did not improve from 0.63910
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.8538 - accuracy: 0.7038 - val_loss: 1.0639 - val_accuracy: 0.6381
# Epoch 91/200
# 1246/1250 [============================>.] - ETA: 0s - loss: 0.8469 - accuracy: 0.7013
# Epoch 91: val_accuracy improved from 0.63910 to 0.63930, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.8467 - accuracy: 0.7014 - val_loss: 1.0637 - val_accuracy: 0.6393
# Epoch 92/200
# 1246/1250 [============================>.] - ETA: 0s - loss: 0.8424 - accuracy: 0.7073
# Epoch 92: val_accuracy improved from 0.63930 to 0.64000, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.8424 - accuracy: 0.7074 - val_loss: 1.0666 - val_accuracy: 0.6400
# Epoch 93/200
# 1250/1250 [==============================] - ETA: 0s - loss: 0.8464 - accuracy: 0.7052
# Epoch 93: val_accuracy did not improve from 0.64000
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.8464 - accuracy: 0.7052 - val_loss: 1.0638 - val_accuracy: 0.6391
# Epoch 94/200
# 1242/1250 [============================>.] - ETA: 0s - loss: 0.8385 - accuracy: 0.7077
# Epoch 94: val_accuracy did not improve from 0.64000
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.8399 - accuracy: 0.7074 - val_loss: 1.0652 - val_accuracy: 0.6387
# Epoch 95/200
# 1243/1250 [============================>.] - ETA: 0s - loss: 0.8365 - accuracy: 0.7066
# Epoch 95: val_accuracy did not improve from 0.64000
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.8363 - accuracy: 0.7068 - val_loss: 1.0647 - val_accuracy: 0.6375
# Epoch 96/200
# 1239/1250 [============================>.] - ETA: 0s - loss: 0.8331 - accuracy: 0.7086
# Epoch 96: val_accuracy did not improve from 0.64000
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.8329 - accuracy: 0.7086 - val_loss: 1.0665 - val_accuracy: 0.6391
# Epoch 97/200
# 1241/1250 [============================>.] - ETA: 0s - loss: 0.8293 - accuracy: 0.7101
# Epoch 97: val_accuracy improved from 0.64000 to 0.64110, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.8296 - accuracy: 0.7100 - val_loss: 1.0651 - val_accuracy: 0.6411
# Epoch 98/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.8270 - accuracy: 0.7096
# Epoch 98: val_accuracy did not improve from 0.64110
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.8270 - accuracy: 0.7097 - val_loss: 1.0650 - val_accuracy: 0.6389
# Epoch 99/200
# 1238/1250 [============================>.] - ETA: 0s - loss: 0.8206 - accuracy: 0.7127
# Epoch 99: val_accuracy did not improve from 0.64110
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.8205 - accuracy: 0.7127 - val_loss: 1.0666 - val_accuracy: 0.6382
# Epoch 100/200
# 1239/1250 [============================>.] - ETA: 0s - loss: 0.8195 - accuracy: 0.7121
# Epoch 100: val_accuracy improved from 0.64110 to 0.64230, saving model to /tmp/modelchk
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.8192 - accuracy: 0.7124 - val_loss: 1.0653 - val_accuracy: 0.6423
# Epoch 101/200
# 1245/1250 [============================>.] - ETA: 0s - loss: 0.8191 - accuracy: 0.7121
# Epoch 101: val_accuracy did not improve from 0.64230
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.8191 - accuracy: 0.7120 - val_loss: 1.0679 - val_accuracy: 0.6401

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:09:08.230215

# %% [markdown]
# ## 6. Evaluamos los resultados
#
# Obtengamos una grafica de como el error y la accuracy van evolucionando en cada epoch en los datos de entrenamiento y en la validación

# %%
_, acc = model.evaluate(x_test_post_vgg, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 63.080

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='val')
plt.legend()
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='val')
plt.legend()
plt.show()

# %% [markdown]
# El coste podemos ver que es estable y es en el epoch 15 que se fija en un valor. Además la accuracy baila alrededor de 0.10. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test_post_vgg)

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label[0]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label[0]].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck

# %% [markdown]
# ## 7. Guardamos el modelo para futuras evaluaciones
#
# Id cambiando los nombres del archivo para ir guardando los diversos proyectos.
# Aquí lo guardamos en "local", pero recordad que lo ideal es que lo guardeis en Google Drive (teneis que montar la unidad, fijar la ruta y allí guardar el modelo .h5)

# %%
ruta_googledrive = "/content/drive/MyDrive/" # A revisar en vuestra instancia

model.save(ruta_googledrive+'cifar10_base_model.h5')
